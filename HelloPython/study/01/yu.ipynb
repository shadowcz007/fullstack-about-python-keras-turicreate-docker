# %%
import requests

# %%
_url = 'http://www.baidu.com/s?wd=ABC'
print _url
# Out:
# http://www.baidu.com/s?wd=ABC

# %%
import requests
print requests
# Out:
# <module 'requests' from '/usr/local/lib/python2.7/dist-packages/requests/__init__.pyc'>

# %%
_url = 'http://www.baidu.com/s?wd=星期天'
print _url
# Out:
# http://www.baidu.com/s?wd=星期天

# %%
_url = 'http://www.baidu.com/s?wd=星期六'
print _url
# Out:
# http://www.baidu.com/s?wd=星期六

# %%
r = requests.get(_url)
print r
# Out:
# <Response [200]>

# %%
print help(r)
# Out:
# Help on Response in module requests.models object:
#
# class Response(__builtin__.object)
#  |  The :class:`Response <Response>` object, which contains a
#  |  server's response to an HTTP request.
#  |
#  |  Methods defined here:
#  |
#  |  __bool__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
#  |
#  |      This attribute checks if the status code of the response is between
#  |      400 and 600 to see if there was a client error or a server error. If
#  |      the status code, is between 200 and 400, this will return True. This
#  |      is **not** a check to see if the response code is ``200 OK``.
#  |
#  |  __enter__(self)
#  |
#  |  __exit__(self, *args)
#  |
#  |  __getstate__(self)
#  |
#  |  __init__(self)
#  |
#  |  __iter__(self)
#  |      Allows you to use a response as an iterator.
#  |
#  |  __nonzero__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
#  |
# ...

# %%
print help lanhaixiao(r)
# Out:
#   File "<ipython-input-13-de0bf17fb9df>", line 1
#     print help lanhaixiao(r)
#                         ^
# SyntaxError: invalid syntax

# %%
print help zhengshuang(r)
# Out:
#   File "<ipython-input-14-4cfc83a3bf01>", line 1
#     print help zhengshuang(r)
#                          ^
# SyntaxError: invalid syntax

# %%
print r.txt
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-15-b1f3a55e4e59> in <module>()
# ----> 1 print r.txt
#
# AttributeError: 'Response' object has no attribute 'txt'

# %%
print r.text
# Out:
# <!DOCTYPE html>
# <!--STATUS OK-->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <html>
# 	<head>
#
# 		<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# 		<meta http-equiv="content-type" content="text/html;charset=utf-8">
# 		<meta content="always" name="referrer">
#         <meta name="theme-color" content="#2932e1">
#         <link rel="shortcut icon" href="/favicon.ico" type="image/x-icon" />
#         <link rel="icon" sizes="any" mask href="//www.baidu.com/img/baidu_85beaf5496f291521eb75ba38eacbd87.svg">
#         <link rel="search" type="application/opensearchdescription+xml" href="/content-search.xml" title="百度搜索" />
#
#
# <title>ABC_百度搜索</title>
#
#
#
#
# <style data-for="result" type="text/css" id="css_newi_result">body{color:#333;background:#fff;padding:6px 0 0;margin:0;position:relative;min-width:900px}
# body,th,td,.p1,.p2{font-family:arial}
# ...

# %%
print len('120304adbffejoijgojoijoij')
# Out:
# 25

# %%
def yu(w):
    t=len(w)
    return t

# %%
yu('uiiiuihuihuhi')
# Out:
# 13

# %%
def yu(w):
    c=len(w)*4
    return c

# %%
yu("dhlhldsjhlkja")
# Out:
# 52

# %%
yu("dhlhldsjhlkja")>10
# Out:
# True

# %%
yu("dhlhldsjhlkja")>10 or (yu("dhlhldsjhlkja")==0)
# Out:
# True

# %%
if yu("dhlhldsjhlkja")>10 or (yu("dhlhldsjhlkja")==0) :
    print 0
    
else:
    print 1
# Out:
# 0

# %%
import requests
def page(word):
    _url="http://www.baidu.com/s?wd="
    r=requests.get(_url+word)
    print r
    if r.status_code==200:
        return r.text

# %%
page('cat')
# Out:
# <Response [200]>
# ...

# %%
html="""
<html><head><title>标题党</title></head>
<body>
<p class="title"><b>我是标题党</b></p >

<p class="story">欢迎关注微信公众号Design-AI-Lab,感谢活动主办方
<a href=" " class="company" id="get">学会Get</a >，助力用户get一项技能</p >

<p class="story">... ...</p >
"""

# %%
from bs4 import BeautifulSoup

# %%
sp=BeautifulSoup(html)
print sp
# Out:
# <html><head><title>标题党</title></head>
# <body>
# <p class="title"><b>我是标题党</b></p>
# <p class="story">欢迎关注微信公众号Design-AI-Lab,感谢活动主办方
# <a class="company" href=" " id="get">学会Get</a>，助力用户get一项技能</p>
# <p class="story">... ...</p>
# </body></html>
# /usr/local/lib/python2.7/dist-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 174 of the file /usr/lib/python2.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html.parser")
#
#   markup_type=markup_type))

# %%
print html
# Out:
# <html><head><title>标题党</title></head>
# <body>
# <p class="title"><b>我是标题党</b></p >
#
# <p class="story">欢迎关注微信公众号Design-AI-Lab,感谢活动主办方
# <a href=" " class="company" id="get">学会Get</a >，助力用户get一项技能</p >
#
# <p class="story">... ...</p >

# %%
get=sp.find(id="get")

# %%
print get
# Out:
# <a class="company" href=" " id="get">学会Get</a>

# %%
print sp.find(class_="story").get_text()
# Out:
# 欢迎关注微信公众号Design-AI-Lab,感谢活动主办方
# 学会Get，助力用户get一项技能

# %%
get=sp.find("title")

# %%
print get
# Out:
# <title>标题党</title>

# %%
import requests
from bs4 import BeautifulSoup
def init(html):
    soup = BeautifulSoup(html)
    results = []
    result_set = soup.find(id='content_left')
    result_set = result_set.find_all('div', class_='c-container')
    for i in range(len(result_set)):
        result = result_set[i]
        abstract = __get_abstract(result)     
        results.append(abstract)
    
    return results

def __get_abstract(result_div):
    if 'result-op' not in result_div['class']:  # 不是软广
        r_from = result_div.find(class_='c-abstract')
        if not r_from:
            return u'-'
        for em in r_from.find_all('em'):  # 移除abstract中的em标签
            em.unwrap()
        #print 0
       # print r_from.get_text()
        return r_from.get_text()
    else:
        return u'-'

# %%
import requests
from bs4 import BeautifulSoup

def init(html):
    # 初始化
    #print help(BeautifulSoup)
    soup = BeautifulSoup(html)
    results = []
    
    # 获取结果来源
    result_set = soup.find(id='content_left')  # 结果全显示在页面左边
    result_set = result_set.find_all('div', class_='c-container')  # 结果class固定，其余为硬广

    for i in range(len(result_set)):  # 因为要index所以就用range来
        result = result_set[i]  # 其实就是result_div

        abstract = __get_abstract(result)
           
        results.append(abstract)
    
    return results

# 获取abstract
def __get_abstract(result_div):
    if 'result-op' not in result_div['class']:  # 不是软广
        r_from = result_div.find(class_='c-abstract')
        if not r_from:
            return u'-'
        for em in r_from.find_all('em'):  # 移除abstract中的em标签
            em.unwrap()
        #print 0
       # print r_from.get_text()
        return r_from.get_text()
    else:
        return u'-'

# %%
html="""
<html><head><title>标题党</title></head>
<body>
<p class="title"><b>我是标题党</b></p >
<p class="story">欢迎关注微信公众号Design-AI-Lab,感谢活动主办方
<a href=" " class="company" id="content_left">学会Ge<div class="c-container">iii</div>t</a >，助力用户get一项技能</p >

<p class="story">... ...</p >
"""

# %%
init(html)
# Out:
# [u'-']

# %%
def search(keyword):
    _page=page(keyword)
    #print _page
    results=init(_page)
    
    
    return results

# %%
import json
def printJson(ky):
    print(json.dumps(ky,ensure_ascii=False, encoding='UTF-8'))coun
# Out:
#   File "<ipython-input-153-3e724b69d74b>", line 3
#     print(json.dumps(ky,ensure_ascii=False, encoding='UTF-8'))coun
#                                                                  ^
# SyntaxError: invalid syntax

# %%
u=search ('标题')
print printJson(u)
# Out:
# <Response [200]>
# ["-", "2016年2月23日 - 起标题注意几点:一、语言要简练;二、以动词为主,不要用形容词和虚词,尤其是不要出现“的地得着了过”,至于为什么,你念两遍就知道了;三、不要在标题中出现复...", "2017年3月13日 - 新媒体爆款标题完全攻略。... 这类内容中,有一些是新闻属性较强的,比如某大佬的新发言,某大厂的新动作等,这类内容的标题只要把相关关键词都怼上去,就...", "-", "找标语、口号,上标语大全网。国内最大最全的标语口号资源网站,标语行业资讯门户网站。提供企业标语,企业文化标语,工厂标语,车间标语,安全生产标语,环保标语,品质标语...", "[专业]答案:在Word中,可以自动生成目录,其具体的操作步骤: 一、设置标题格式 1、选中文章中的所有一级标题; 2、单击开始选项卡上的标题1,如图所示; 仿照步骤1、2...", "2016年5月30日 - 这种标题是非常常见的一种类型,属于留悬念式的标题类型。主要就是为了吸引别人好奇心,以此来吸引别人,其实在微信里面,大家也应该都看到过这种类型的标...", "2018年1月25日 - 标题党是互联网上利用各种颇具创意的标题吸引网友眼球,以达到各种目的一小部分网站管理者和网民的总称。其主要行为简而言之即发帖的标题严重夸张,帖子...", "2016年8月31日 - 随着互联网行业快速发展,“标题党”曾是一个极具讽刺的名词。但随着编辑行业自己的方法论、系统的编辑规范也都出来,在互联网的新时代,“假大空”的...", "-"]
# None

# %%
ps='12345678999999'
ps.count('9')
# Out:
# 6

# %%
ps='12345678999999'
ps.count('9')
ps=['adf2','word','you are']
strs=''.join(ps)
print strs
# Out:
# adf2wordyou are

# %%
obj={
    'index':1,
    'sex' :0,
    'name':'karen',
    'children':[{
            'name':'xiaoyu'
        }]
    }


print obj['name']
# Out:
# karen

# %%
def guessAnswer (question,answers):
    _res=search(question)
    _strs=''.join(_res)
    _guess={ }
    for ans in answers:
        _guess[ans]=_strs.count(ans)
        
    return _guess

# %%
question=u'下列哪个戏种被称为中国的百戏之祖'
answers=[u'黄梅戏',u'越剧',u'昆曲']

# %%
opppp=guessAnswer (question,answers)
# Out:
# <Response [200]>

# %%
printJson(opppp)
# Out:
# {"昆曲": 6, "越剧": 1, "黄梅戏": 1}

# %%
from jieba import lcut as jc

p=jc(answers[2],cut_all=True)
printJson(p)
# Out:
# ["C", "", "感觉", "很", "舒服", "", "", "增强", "免疫", "免疫力"]
