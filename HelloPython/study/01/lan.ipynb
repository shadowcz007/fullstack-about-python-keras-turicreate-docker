# %%
import requests
print requests
# Out:
# <module 'requests' from '/usr/local/lib/python2.7/dist-packages/requests/__init__.pyc'>

# %%
_url = 'http://www.baidu.com/s?wd=星期天' 
print _url
# Out:
# http://www.baidu.com/s?wd=星期天

# %%
r = requests.get(_url)
print r
# Out:
# <Response [200]>

# %%
print r.text
# Out:
# <!DOCTYPE html>
# <!--STATUS OK-->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <html>
# 	<head>
#
# 		<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# 		<meta http-equiv="content-type" content="text/html;charset=utf-8">
# 		<meta content="always" name="referrer">
#         <meta name="theme-color" content="#2932e1">
#         <link rel="shortcut icon" href="/favicon.ico" type="image/x-icon" />
#         <link rel="icon" sizes="any" mask href="//www.baidu.com/img/baidu_85beaf5496f291521eb75ba38eacbd87.svg">
#         <link rel="search" type="application/opensearchdescription+xml" href="/content-search.xml" title="百度搜索" />
#
#
# <title>星期天_百度搜索</title>
#
#
#
#
# <style data-for="result" type="text/css" id="css_newi_result">body{color:#333;background:#fff;padding:6px 0 0;margin:0;position:relative;min-width:900px}
# body,th,td,.p1,.p2{font-family:arial}
# ...

# %%
print len('httpcdnsjcnjdsxsxs')
print len([10,'2p',3,4])
# Out:
# 18
# 4

# %%
def haixiao(w):
    C=len(w)*4
    return C

# %%
haixiao('dvdvdbv')
# Out:
# 28

# %%
haixiao('chhduhcidhcduihc')>10
# Out:
# True

# %%
if haixiao('xbdjscbhjbjc')>10 or haixiao('xbdjscbhjbjc')=0 
return False
else:haixiao('chhduhcidhcduihc')<10
    return True
# Out:
#   File "<ipython-input-25-3cf7a617990b>", line 1
#     if haixiao('xbdjscbhjbjc')>10 or haixiao('xbdjscbhjbjc')=0
#                                                             ^
# SyntaxError: invalid syntax

# %%
import requests 
def page(word):
    url='http://www.baidu.com/s?wd='
    r=requests.get(url+word)
    print r
    if r.status_code==200:
        return r.text
    else:
        ptint(r.status_code)
        return False

# %%
page("狗")
# Out:
# <Response [200]>
# ...

# %%
import json
def printJson(ky):
    print(json.dumps(ky,ensure_ascii=False, encoding='UTF-8'))

# %%
from bs4 import BeautifulSoup

html="""
<html><head><title>标题党</title></head>
<body>
<p class="title"><b>我是标题党</b></p >

<p class="story">欢迎关注微信公众号Design-AI-Lab,感谢活动主办方
<a href=" " class="company" id="get">学会Get</a>，助力用户get一项技能</p>

<p class="story">... ...</p >
"""

# %%
sp=BeautifulSoup(html)

# %%
print sp
# Out:
# <html><head><title>标题党</title></head>
# <body>
# <p class="title"><b>我是标题党</b></p>
# <p class="story">欢迎关注微信公众号Design-AI-Lab,感谢活动主办方
# <a class="company" href=" " id="get">学会Get</a>，助力用户get一项技能</p>
# <p class="story">... ...</p>
# </body></html>

# %%
get=sp.find(id='get')

# %%
print get
# Out:
# <a class="company" href=" " id="get">学会Get</a>

# %%
print sp.find_all('a',class_='company')[0]
# Out:
# <a class="company" href=" " id="get">学会Get</a>

# %%
print sp.find(class_='story').get_text()
# Out:
# 欢迎关注微信公众号Design-AI-Lab,感谢活动主办方
# 学会Get，助力用户get一项技能

# %%
get=sp.find('title')

# %%
print get
# Out:
# <a class="company" href=" " id="get">学会Get</a>

# %%
print sp.find('title').get_text()
# Out:
# 标题党

# %%
import requests
from bs4 import BeautifulSoup
def init(html):
    soup = BeautifulSoup(html)
    results = []
    result_set = soup.find(id='content_left')
    result_set = result_set.find_all('div', class_='c-container')
    for i in range(len(result_set)):
        result = result_set[i]
        abstract = result.get_text()     
        results.append(abstract)
        return results

# %%
html="""
<html><head><title>标题党</title></head>
<body>
<p class="title"><b>我是标题党</b></p >
<p class="story">欢迎关注微信公众号Design-AI-Lab,感谢活动主办方
<a href=" " class="company" id="content_left">学会Ge<div class="c-container">iii</div>t</a>，助力用户get一项技能</p >

<p class="story">... ...</p >
"""

# %%
init(html)
# Out:
# [u'iii']

# %%
def search(keyword):
    _page = page(keyword)
    results = init(_page)

    return results

# %%
y=search('黄梅戏')
print  y
# Out:
# <Response [200]>
# AttributeErrorTraceback (most recent call last)
# <ipython-input-108-a8679f77292d> in <module>()
# ----> 1 y=search('黄梅戏')
#       2 print  y
#
# <ipython-input-104-de3060dcce6f> in search(keyword)
#       1 def search(keyword):
#       2     _page = page(keyword)
# ----> 3     results = init(_page)
#       4
#       5     return results
#
# <ipython-input-93-7d54d0e60b62> in init(html)
#       5     results = []
#       6     result_set = soup.find(id='content_left')
# ----> 7     result_set = result_set.find_all('div', class_='c-container')
#       8     for i in range(len(result_set)):
#       9         result = result_set[i]
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
import json
def printJson(ky):
    print(json.dumps(ky,ensure_ascii=False, encoding='UTF-8'))

# %%
def  guessAnswers(question,answer):
    _re

# %%
ps='434454356767768'
ps.count('4')
ps=['xscdaxasxas','sxcxsdcsd','xsacascadc']
strs=''.join(ps)
print strs
# Out:
# xscdaxasxassxcxsdcsdxsacascadc

# %%
ps=('xscdaxasxassxcxsdcsdxsacascadc')
ps.count('x')
# Out:
# 6

# %%
obj={
    'index':1,
    'sex':0,
    'name':'i love',
    'children':[{
            'name':'small rain'
        }]
}


obj['name']
# Out:
# 'i love'

# %%
question=u'下列哪个戏种被称为中国的百戏之祖'
answers=[u'黄梅戏',u'越剧',u'昆曲']

# %%
def guessAnswer(question,answers):
    _res=search(question)
    _strs=''.join(_res)
    _guess={
            
        }
    for ans in answers:
        _guess[ans]=_strs.count(ans)
            
    return _guess

# %%
abc=guessAnswer(question,answers)
# Out:
# <Response [200]>

# %%
print printJson(abc)
# Out:
# {"昆曲": 2, "越剧": 0, "黄梅戏": 0}
# None

# %%
question=u'如果我们长期在很高的氧浓度下呼吸，会？'
answers=[u'A 觉得轻飘飘的',u'B 脑中毒，精神混乱，记忆丧失',u'C 感觉很舒服，增强免疫力']

# %%
from jieba import lcut as jc

p=jc(answers[2],cut_all=True)
printJson(p)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.379 seconds.
# Prefix dict has been built succesfully.
# ["C", "", "感觉", "很", "舒服", "", "", "增强", "免疫", "免疫力"]
